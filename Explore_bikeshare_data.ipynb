# %% [markdown]
# ### Explore Bike Share Data
#
# For this project, your goal is to ask and answer three questions about the available bikeshare data from Washington, Chicago, and New York.  This notebook can be submitted directly through the workspace when you are confident in your results.
#
# You will be graded against the project [Rubric](https://review.udacity.com/#!/rubrics/2508/view) by a mentor after you have submitted.  To get you started, you can use the template below, but feel free to be creative in your solutions!

# %%
# Importing library
library(ggplot2)
library(lubridate)
require(tidyverse)
library(dplyr)

# %%
ny = read.csv('new_york_city.csv')
wash = read.csv('washington.csv')
chi = read.csv('chicago.csv')

# %%
head(ny)
# Out:
#   X       Start.Time          End.Time            Trip.Duration
# 1 5688089 2017-06-11 14:55:05 2017-06-11 15:08:21  795
# 2 4096714 2017-05-11 15:30:11 2017-05-11 15:41:43  692
# 3 2173887 2017-03-29 13:26:26 2017-03-29 13:48:31 1325
# 4 3945638 2017-05-08 19:47:18 2017-05-08 19:59:01  703
# 5 6208972 2017-06-21 07:49:16 2017-06-21 07:54:46  329
# 6 1285652 2017-02-22 18:55:24 2017-02-22 19:12:03  998
#   Start.Station           End.Station            User.Type  Gender Birth.Year
# 1 Suffolk St & Stanton St W Broadway & Spring St Subscriber Male   1998
# 2 Lexington Ave & E 63 St 1 Ave & E 78 St        Subscriber Male   1981
# 3 1 Pl & Clinton St       Henry St & Degraw St   Subscriber Male   1987
# 4 Barrow St & Hudson St   W 20 St & 8 Ave        Subscriber Female 1986
# 5 1 Ave & E 44 St         E 53 St & 3 Ave        Subscriber Male   1992
# 6 State St & Smith St     Bond St & Fulton St    Subscriber Male   1986

# %%
summary(ny)
# Out:
#        X                         Start.Time                   End.Time
#  Min.   :     47   2017-05-11 18:26:10:    3   2017-01-03 08:54:10:    2
#  1st Qu.:1712425   2017-01-04 13:58:24:    2   2017-01-04 17:21:55:    2
#  Median :3418634   2017-01-09 09:36:01:    2   2017-01-05 17:25:17:    2
#  Mean   :3415873   2017-01-21 15:36:56:    2   2017-01-12 08:34:01:    2
#  3rd Qu.:5123382   2017-01-21 17:49:59:    2   2017-01-12 09:41:54:    2
#  Max.   :6816152   2017-01-21 20:08:29:    2   2017-01-12 20:34:42:    2
#                    (Other)            :54757   (Other)            :54758
#  Trip.Duration                     Start.Station
#  Min.   :     61.0   Pershing Square North:  592
#  1st Qu.:    368.0   W 21 St & 6 Ave      :  385
#  Median :    610.0   Broadway & E 22 St   :  383
#  Mean   :    903.6   E 17 St & Broadway   :  380
#  3rd Qu.:   1051.0   West St & Chambers St:  364
#  Max.   :1088634.0   W 20 St & 11 Ave     :  329
# ...

# %%
head(wash)
# Out:
#   X       Start.Time          End.Time            Trip.Duration
# 1 1621326 2017-06-21 08:36:34 2017-06-21 08:44:43  489.066
# 2  482740 2017-03-11 10:40:00 2017-03-11 10:46:00  402.549
# 3 1330037 2017-05-30 01:02:59 2017-05-30 01:13:37  637.251
# 4  665458 2017-04-02 07:48:35 2017-04-02 08:19:03 1827.341
# 5 1481135 2017-06-10 08:36:28 2017-06-10 09:02:17 1549.427
# 6 1148202 2017-05-14 07:18:18 2017-05-14 07:24:56  398.000
#   Start.Station
# 1 14th & Belmont St NW
# 2 Yuma St & Tenley Circle NW
# 3 17th St & Massachusetts Ave NW
# 4 Constitution Ave & 2nd St NW/DOL
# 5 Henry Bacon Dr & Lincoln Memorial Circle NW
# 6 1st & K St SE
#   End.Station                                         User.Type
# 1 15th & K St NW                                      Subscriber
# 2 Connecticut Ave & Yuma St NW                        Subscriber
# 3 5th & K St NW                                       Subscriber
# 4 M St & Pennsylvania Ave NW                          Customer
# ...

# %%
summary(wash)
# Out:
#        X                         Start.Time                   End.Time
#  Min.   :      7   2017-02-19 12:19:00:    6   2017-03-09 17:54:00:    7
#  1st Qu.: 434587   2017-02-20 11:35:00:    6   2017-03-28 18:11:00:    7
#  Median : 872858   2017-02-24 17:46:00:    6   2017-01-13 17:48:00:    6
#  Mean   : 873881   2017-03-01 08:20:00:    6   2017-01-31 08:49:00:    6
#  3rd Qu.:1313305   2017-03-02 08:39:00:    6   2017-02-13 18:09:00:    6
#  Max.   :1751392   2017-03-09 17:31:00:    6   2017-02-20 11:38:00:    6
#                    (Other)            :89015   (Other)            :89013
#  Trip.Duration                                   Start.Station
#  Min.   :    60.3   Columbus Circle / Union Station     : 1700
#  1st Qu.:   410.9   Lincoln Memorial                    : 1546
#  Median :   707.0   Jefferson Dr & 14th St SW           : 1488
#  Mean   :  1234.0   Massachusetts Ave & Dupont Circle NW: 1219
#  3rd Qu.:  1233.2   Jefferson Memorial                  : 1068
# ...

# %%
head(chi)
# Out:
#   X       Start.Time          End.Time            Trip.Duration
# 1 1423854 2017-06-23 15:09:32 2017-06-23 15:14:53  321
# 2  955915 2017-05-25 18:19:03 2017-05-25 18:45:53 1610
# 3    9031 2017-01-04 08:27:49 2017-01-04 08:34:45  416
# 4  304487 2017-03-06 13:49:38 2017-03-06 13:55:28  350
# 5   45207 2017-01-17 14:53:07 2017-01-17 15:02:01  534
# 6 1473887 2017-06-26 09:01:20 2017-06-26 09:11:06  586
#   Start.Station                 End.Station                  User.Type  Gender
# 1 Wood St & Hubbard St          Damen Ave & Chicago Ave      Subscriber Male
# 2 Theater on the Lake           Sheffield Ave & Waveland Ave Subscriber Female
# 3 May St & Taylor St            Wood St & Taylor St          Subscriber Male
# 4 Christiana Ave & Lawrence Ave St. Louis Ave & Balmoral Ave Subscriber Male
# 5 Clark St & Randolph St        Desplaines St & Jackson Blvd Subscriber Male
# 6 Clinton St & Washington Blvd  Canal St & Taylor St         Subscriber Male
#   Birth.Year
# 1 1992
# 2 1992
# ...

# %%
summary(chi)
# Out:
#        X                         Start.Time                  End.Time
#  Min.   :     36   2017-01-24 07:40:32:   2   2017-04-16 13:16:52:   2
#  1st Qu.: 386722   2017-04-22 13:16:25:   2   2017-04-26 16:29:26:   2
#  Median : 773554   2017-05-27 15:17:50:   2   2017-05-21 16:20:56:   2
#  Mean   : 776721   2017-06-10 13:29:41:   2   2017-05-27 09:58:21:   2
#  3rd Qu.:1171266   2017-06-20 17:05:11:   2   2017-06-25 14:51:35:   2
#  Max.   :1551248   2017-06-21 13:18:52:   2   2017-01-01 00:46:32:   1
#                    (Other)            :8618   (Other)            :8619
#  Trip.Duration                          Start.Station
#  Min.   :   60.0   Streeter Dr & Grand Ave     : 210
#  1st Qu.:  394.2   Lake Shore Dr & Monroe St   : 140
#  Median :  670.0   Clinton St & Washington Blvd: 120
#  Mean   :  937.2   Clinton St & Madison St     : 102
#  3rd Qu.: 1119.0   Canal St & Adams St         : 101
#  Max.   :85408.0   Michigan Ave & Oak St       :  98
# ...

# %%
#creating city columns for ny and chi files
ny$City = 'nyc'
chi$City = 'chi'
wash$City = 'wash'

# %%
colnames(ny)
# Out:
#  [1] "X"             "Start.Time"    "End.Time"      "Trip.Duration"
#  [5] "Start.Station" "End.Station"   "User.Type"     "Gender"
#  [9] "Birth.Year"    "City"

# %%
colnames(wash)
# Out:
# [1] "X"             "Start.Time"    "End.Time"      "Trip.Duration"
# [5] "Start.Station" "End.Station"   "User.Type"     "City"

# %%
colnames(chi)
# Out:
#  [1] "X"             "Start.Time"    "End.Time"      "Trip.Duration"
#  [5] "Start.Station" "End.Station"   "User.Type"     "Gender"
#  [9] "Birth.Year"    "City"

# %% [markdown]
# ### Question 1
#
# > What is the most common start station in each city?
#
# > Is this start station the same every day of the week?

# %%
#Checking the most commonly used start station for Chicago
#Referenced: https://ggplot2.tidyverse.org/reference/coord_flip.html#:~:text=coord_flip.Rd,to%20x%20conditional%20on%20y.
#and https://www.geeksforgeeks.org/data-visualization-with-r-and-ggplot2/
start_stations_c <- chi %>%   
  group_by(Start.Station) %>%
  summarise(n = n()) %>%
  filter(n > 40)


 ggplot(start_stations_c, aes(Start.Station, n))+
  geom_col()+
  labs(title = 'Chicago')+
    coord_flip()
# Out:
# plot without title

# %%
# Sort descending order and show the top five
start_stations_c <- start_stations_c %>% arrange(desc(n))
head(start_stations_c, 5)
# Out:
#   Start.Station                n
# 1 Streeter Dr & Grand Ave      210
# 2 Lake Shore Dr & Monroe St    140
# 3 Clinton St & Washington Blvd 120
# 4 Clinton St & Madison St      102
# 5 Canal St & Adams St          101

# %%
#Checking the most commonly used start station for New York
start_stations_n <- ny %>%   
  group_by(Start.Station) %>%
  summarise(n = n()) %>%
  filter(n > 200)

ggplot(start_stations_n, aes(Start.Station, n))+
  geom_col()+
  labs(title = 'New York')+
    coord_flip()
# Out:
# plot without title

# %%
# Sort descending order and show the top five
start_stations_n <- start_stations_n %>% arrange(desc(n))
head(start_stations_n, 5)
# Out:
#   Start.Station         n
# 1 Pershing Square North 592
# 2 W 21 St & 6 Ave       385
# 3 Broadway & E 22 St    383
# 4 E 17 St & Broadway    380
# 5 West St & Chambers St 364

# %%
#Referenced: https://www.geeksforgeeks.org/group-by-function-in-r-using-dplyr/
#Checking the most commonly used start station for Washington

start_stations_w <- wash %>%   
  group_by(Start.Station) %>%
  summarise(n = n()) %>%
  filter(n > 500)

ggplot(start_stations_w, aes(Start.Station, n))+
  geom_col()+
  labs(title = 'Washington')+
  coord_flip()
# Out:
# plot without title

# %%
# Sort descending order
start_stations_w <- start_stations_w %>% arrange(desc(n))
head(start_stations_w, 5)
# Out:
#   Start.Station                        n
# 1 Columbus Circle / Union Station      1700
# 2 Lincoln Memorial                     1546
# 3 Jefferson Dr & 14th St SW            1488
# 4 Massachusetts Ave & Dupont Circle NW 1219
# 5 Jefferson Memorial                   1068

# %%
#Reducing the dataframes to work with them better
chi_ss <- chi[c("X", "City", "Start.Station")]
wash_ss <- wash[c("X", "City", "Start.Station")]
ny_ss <- ny[c("X", "City", "Start.Station")]

# Merge the selected columns into a single dataframe
ss_merged_df <- rbind(chi_ss, wash_ss, ny_ss)
head(ss_merged_df, 10)
# Out:
#    X       City Start.Station
# 1  1423854 chi  Wood St & Hubbard St
# 2   955915 chi  Theater on the Lake
# 3     9031 chi  May St & Taylor St
# 4   304487 chi  Christiana Ave & Lawrence Ave
# 5    45207 chi  Clark St & Randolph St
# 6  1473887 chi  Clinton St & Washington Blvd
# 7   961916 chi  Ashland Ave & Lake St
# 8    65924 chi  Larrabee St & Kingsbury St
# 9   606841 chi  Sedgwick St & Huron St
# 10  135470 chi  Stetson Ave & South Water St

# %%
#referenced: https://stackoverflow.com/questions/12018499/how-to-put-labels-over-geom-bar-for-each-bar-in-r-with-ggplot2

# Calculate the counts of start stations by city
start_stations_counts <- ss_merged_df %>%
  group_by(City, Start.Station) %>%
  summarise(Count = n()) %>%
  filter(!is.na(Start.Station) & Start.Station != "") %>%
  arrange(City, desc(Count))


# Select the top three start stations for each city
top_start_stations <- start_stations_counts %>%
  group_by(City) %>%
  top_n(n = 3, wt = Count)

# using ggplot to chart the top three start stations in each city
ggplot(top_start_stations, aes(x = City, y = Count, fill = Start.Station)) +
  geom_bar(stat = "identity", position = "dodge") +
  geom_text(aes(label = Count), position = position_dodge(width = 0.9), vjust = -0.5, color = "black", size = 3) +  
  labs(title = "Top Three Start Stations by City",
       x = "City",
       y = "Count") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# ###### Results
# The most often used starting station in each city is:
#
# >Chicago - Streeter Dr. & Grand Ave
#
# >New York - Pershing Square North
#
# >Washington - Columbus Circle/Union Station

# %%
#referenced: https://argoshare.is.ed.ac.uk/healthyr_book/missing-values-nas-and-filters.html
# In order to find out if the most popular start station remains popular throughout the week, we need get the day of the week
chi <- chi %>%
  mutate(Start.Day = format(as.Date(Start.Time), "%A"))

wash <- wash %>%
  mutate(Start.Day = format(as.Date(Start.Time), "%A"))

ny <- ny %>%
  mutate(Start.Day = format(as.Date(Start.Time), "%A"))

# Find the most often used Start Station for each day of the week in each dataframe
chi_most_often <- chi %>%
  group_by(Start.Day, Start.Station) %>%
  tally() %>%
  group_by(Start.Day) %>%
  top_n(1, wt = n)

wash_most_often <- wash %>%
  group_by(Start.Day, Start.Station) %>%
  tally() %>%
  group_by(Start.Day) %>%
  filter(!is.na(Start.Station) & Start.Station != "") %>%
  top_n(1, wt = n)


ny_most_often <- ny %>%
  group_by(Start.Day, Start.Station) %>%
  tally() %>%
  group_by(Start.Day) %>%
  top_n(1, wt = n)

# Print the results
chi_most_often
wash_most_often
ny_most_often
# Out:
#   Start.Day Start.Station                n
# 1 Friday    Clinton St & Washington Blvd 27
# 2 Friday    Streeter Dr & Grand Ave      27
# 3 Monday    Clinton St & Washington Blvd 26
# 4 Saturday  Streeter Dr & Grand Ave      56
# 5 Sunday    Streeter Dr & Grand Ave      44
# 6 Thursday  Streeter Dr & Grand Ave      21
# 7 Tuesday   Clinton St & Washington Blvd 24
# 8 Wednesday Canal St & Adams St          25
#   Start.Day Start.Station                   n
# 1 Friday    Columbus Circle / Union Station 260
# 2 Monday    Columbus Circle / Union Station 240
# 3 Saturday  Lincoln Memorial                331
# 4 Sunday    Lincoln Memorial                324
# 5 Thursday  Columbus Circle / Union Station 333
# 6 Tuesday   Columbus Circle / Union Station 320
# 7 Wednesday Columbus Circle / Union Station 346
#   Start.Day Start.Station         n
# 1 Friday    Pershing Square North 103
# 2 Monday    Pershing Square North 101
# 3 Saturday  W 21 St & 6 Ave        45
# ...

# %%
# Create the bar chart to display most often used start station by day of the week
bar_chart_chi <- ggplot(chi_most_often, aes(x = Start.Day, y = n, fill = Start.Station)) +
  geom_bar(stat = "identity", position = "dodge") +
  geom_text(aes(label = n), vjust = -0.5, color = "black", size = 3) +  
  labs(title = "Most Often Used Start Stations in Chicago by Day",
       x = "Day of the Week",
       y = "Count") +
  theme_minimal()

print(bar_chart_chi)
# Out:
# plot without title

# %%
# Create the bar chart to display most often used start station by day of the week
bar_chart_wash <- ggplot(wash_most_often, aes(x = Start.Day, y = n, fill = Start.Station)) +
  geom_bar(stat = "identity", position = "dodge") +
  geom_text(aes(label = n), vjust = -0.5, color = "black", size = 3) + 
  labs(title = "Most Often Used Start Stations in Washington by Day",
       x = "Day of the Week",
       y = "Count") +
  theme_minimal()

print(bar_chart_wash)
# Out:
# plot without title

# %%
# Create the bar chart to display most often used start station by day of the week
bar_chart_ny <- ggplot(ny_most_often, aes(x = Start.Day, y = n, fill = Start.Station)) +
  geom_bar(stat = "identity", position = "dodge") +
  geom_text(aes(label = n), vjust = -0.5, color = "black", size = 3) + 
  labs(title = "Most Often Used Start Stations in New York by Day",
       x = "Day of the Week",
       y = "Count") +
  theme_minimal()

print(bar_chart_ny)
# Out:
# plot without title

# %% [markdown]
# ### Question 1 Results
#
# ##### Most common start station in each city:
#
# ###### Chicago
# > Streeter Dr. and Grand Avenue
#
# ###### New York
# > Pershing Square North
#
# ###### Washington
# > Columbus Circle/Union Station
#
#
# ##### Does this remain constant throughout the week?
#
# ###### Chicago
# > Most days of the week, riders start at Streeter Dr. and Grand Ave.
# > Riders start here most often on Thursday, Saturday and Sunday, and this start station tied with Clinton St. and Washington Blvd on Fridays.
#
# ###### New York
# > Pershing Square North has the most riders 5 days out of the week. These days are weekdays, with Saturday and Sunday having a much lower volume at the top spot. W 21 St. & 6th is more popular on Saturdays, and West St. & Chambers St. is on Sunday.
#
# ###### Washington
# > Columbus Circle/Union Station is the most popular start station on weekdays, but Lincoln memorial is the most popular on Weekends.

# %% [markdown]
# ### Question 2
#
# >What is the most common age of riders in each city (excluding Washington)?
#
# >Does this vary when considering gender?

# %%
#calculating age from birth year and creating a range for the ages
calculate_age_range <- function(data) {
  data %>%
    mutate(Age = floor((as.integer(format(Sys.Date(), "%Y")) - Birth.Year) / 10) * 10) %>%
    group_by(Age) %>%
    summarise(count = n()) %>%
    filter(Age >= 10 & Age < 100) %>% #filtered out outlier ages
    arrange(desc(count))
}

# Calculate the most common age range counting by 10 for each dataframe
ny_age_range <- calculate_age_range(ny)
chi_age_range <- calculate_age_range(chi)

ny_age_range
chi_age_range
# Out:
#   Age count
# 1 30  18284
# 2 40  13030
# 3 50   9202
# 4 60   5419
# 5 20   2202
# 6 70   1261
# 7 80    127
# 8 90      6
#   Age count
# 1 30  3326
# 2 40  1672
# 3 50   944
# 4 60   506
# 5 20   306
# 6 70   115
# 7 80     7
# 8 90     1

# %%
create_bar_chart <- function(data, city) {
  ggplot(data, aes(x = Age, y = count, fill = factor(Age))) +
    geom_bar(stat = "identity") +
    geom_text(aes(label = count), vjust = -0.5, color = "black", size = 3) +
    labs(title = paste("Most Common Age Range in", city),
         x = "Age Range",
         y = "Count") +
    theme_minimal()
}

# Create a bar chart with data labels for ny_age_range
bar_chart_ny <- create_bar_chart(ny_age_range, "New York")

# Create a bar chart with data labels for chi_age_range
bar_chart_chi <- create_bar_chart(chi_age_range, "Chicago")

# Print the bar charts
print(bar_chart_ny)
print(bar_chart_chi)
# Out:
# plot without title
# plot without title

# %%
#referenced: https://dplyr.tidyverse.org/reference/mutate.html
#calculating age from birth year and creating a range for the ages
calculate_age_range <- function(data) {
  data %>%
    mutate(Age = floor((as.integer(format(Sys.Date(), "%Y")) - Birth.Year) / 10) * 10) %>%
    group_by(Age, Gender) %>%
    summarise(count = n()) %>%
    filter(Age >= 10 & Age < 100) %>% #filtered out outlier ages
    arrange(desc(count))
}

# Calculate the most common age range counting by 10 for each dataframe
ny_age_range <- calculate_age_range(ny)
chi_age_range <- calculate_age_range(chi)

ny_age_range
chi_age_range
# Out:
#    Age Gender count
# 1  30  Male   13220
# 2  40  Male   10099
# 3  50  Male    7072
# 4  30  Female  5012
# 5  60  Male    4105
# 6  40  Female  2861
# 7  50  Female  2091
# 8  20  Male    1577
# 9  60  Female  1305
# 10 70  Male    1005
# 11 20  Female   611
# 12 70  Female   253
# 13 80  Male     106
# 14 40            70
# 15 30            52
# 16 50            39
# 17 80  Female    19
# 18 20            14
# 19 60             9
# 20 90  Female     5
# 21 70             3
# 22 80             2
# 23 90  Male       1
#    Age Gender count
# 1  30  Male   2374
# 2  40  Male   1300
# 3  30  Female  952
# 4  50  Male    760
# 5  60  Male    412
# 6  40  Female  371
# 7  20  Male    203
# 8  50  Female  184
# 9  20  Female  103
# 10 70  Male     96
# 11 60  Female   94
# 12 70  Female   19
# 13 80  Male      7
# 14 40            1
# 15 90  Male      1

# %%
#displaying age ranges by gender 
ggplot(ny_age_range, aes(x = factor(Age), y = count, fill = Gender)) +
  geom_bar(stat = "identity", position = "dodge") +
  labs(title = "Age Range by Gender - NY",
       x = "Age Range",
       y = "Count",
       fill = "Gender") +
  theme_minimal()
# Out:
# plot without title

# %%
# Bar chart for chi_age_range
ggplot(chi_age_range, aes(x = factor(Age), y = count, fill = Gender)) +
  geom_bar(stat = "identity", position = "dodge") +
  labs(title = "Age Range by Gender - CHI",
       x = "Age Range",
       y = "Count",
       fill = "Gender") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# ### Question 2 Results
#
# ###### What is the most common age range?
#
# > The most common age range for both New York and Chicago is between 30 and 39. This is followed by people in their 40's.
#
# ###### What is the most common age range when accounting for gender?
#
# > For both Male and female there in both cities is still in the 30's. One thing we see though is that there are significantly more male riders regardless of age range.
#
#
#
# Note: Washington did not provide birth year and we could not calculate age range.

# %% [markdown]
# ### Question 3
#
# > What time of day is most common in each city?
#
# > What is the most common end time in each city?

# %%
#create new column called start.hour

create_start_hour_column <- function(data) {
  data %>%
    mutate(Start.Time = ymd_hms(Start.Time),  # Convert Start.Time to proper date/time format
           start.hour = hour(Start.Time))     # Extract hour component
}

wash <- create_start_hour_column(wash)
ny <- create_start_hour_column(ny)
chi <- create_start_hour_column(chi)

wash
# Out:
#       X       Start.Time          End.Time            Trip.Duration
# 1     1621326 2017-06-21 08:36:34 2017-06-21 08:44:43  489.066
# 2      482740 2017-03-11 10:40:00 2017-03-11 10:46:00  402.549
# 3     1330037 2017-05-30 01:02:59 2017-05-30 01:13:37  637.251
# 4      665458 2017-04-02 07:48:35 2017-04-02 08:19:03 1827.341
# 5     1481135 2017-06-10 08:36:28 2017-06-10 09:02:17 1549.427
# 6     1148202 2017-05-14 07:18:18 2017-05-14 07:24:56  398.000
# 7     1594275 2017-06-19 08:41:43 2017-06-19 09:00:08 1105.429
# 8     1601832 2017-06-20 05:54:42 2017-06-20 06:05:18  636.218
# 9      574182 2017-03-24 20:37:00 2017-03-24 20:42:00  328.530
# 10     327058 2017-02-20 21:12:00 2017-02-20 21:31:00 1188.090
# 11     854729 2017-04-17 02:50:51 2017-04-17 03:05:17  866.689
# 12     721887 2017-04-08 01:12:48 2017-04-08 01:52:33 2385.411
# 13     143181 2017-01-26 20:01:00 2017-01-26 20:17:00  951.457
# 14      26953 2017-01-06 17:36:00 2017-01-06 17:43:00  448.628
# ...

# %%
#finding the most popular start hour
find_most_popular_start_hour <- function(data) {
  data %>%
    group_by(X, City, start.hour) %>%
    summarise(count = n()) %>%
    filter(count == max(count))
}

wash_most_popular_start_hour <- find_most_popular_start_hour(wash)
ny_most_popular_start_hour <- find_most_popular_start_hour(ny)
chi_most_popular_start_hour <- find_most_popular_start_hour(chi)

wash_most_popular_start_hour 
ny_most_popular_start_hour  
chi_most_popular_start_hour
# Out:
#       X       City start.hour count
# 1       7     wash  0         1
# 2      13     wash  0         1
# 3      21     wash  0         1
# 4      61     wash  0         1
# 5      86     wash  1         1
# 6     120     wash  1         1
# 7     121     wash  1         1
# 8     132     wash NA         1
# 9     157     wash  2         1
# 10    170     wash  2         1
# 11    173     wash  2         1
# 12    180     wash  2         1
# 13    203     wash  2         1
# 14    230     wash  3         1
# 15    270     wash  7         1
# 16    272     wash  7         1
# 17    281     wash  8         1
# 18    285     wash  8         1
# 19    315     wash  8         1
# 20    323     wash  8         1
# 21    330     wash  8         1
# 22    354     wash  9         1
# 23    384     wash  9         1
# 24    406     wash  9         1
# 25    434     wash  9         1
# 26    436     wash  9         1
# 27    451     wash 10         1
# 28    469     wash 10         1
# ...

# %%
#creating a merged dataframe to work with - plotting the above data was cumbersome
start_hr_merge <- rbind(chi, ny)

#need to drop the gender and birth year columns to merge with wash
start_hr_merge <- start_hr_merge %>%
  select(-c("Gender", "Birth.Year"))

#complete the merge
start_hr_merge <- rbind(start_hr_merge, wash)

start_hr_merge
# Out:
#        X       Start.Time          End.Time            Trip.Duration
# 1      1423854 2017-06-23 15:09:32 2017-06-23 15:14:53  321
# 2       955915 2017-05-25 18:19:03 2017-05-25 18:45:53 1610
# 3         9031 2017-01-04 08:27:49 2017-01-04 08:34:45  416
# 4       304487 2017-03-06 13:49:38 2017-03-06 13:55:28  350
# 5        45207 2017-01-17 14:53:07 2017-01-17 15:02:01  534
# 6      1473887 2017-06-26 09:01:20 2017-06-26 09:11:06  586
# 7       961916 2017-05-26 09:41:44 2017-05-26 09:46:25  281
# 8        65924 2017-01-21 14:28:38 2017-01-21 14:40:41  723
# 9       606841 2017-04-20 16:08:51 2017-04-20 16:20:20  689
# 10      135470 2017-02-06 18:00:47 2017-02-06 18:09:00  493
# 11      175805 2017-02-15 07:09:55 2017-02-15 07:14:56  301
# 12       71678 2017-01-22 15:15:45 2017-01-22 15:31:02  917
# 13       19061 2017-01-08 16:03:00 2017-01-08 16:07:37  277
# 14     1023296 2017-05-30 15:46:18 2017-05-30 15:52:12  354
# ...

# %%
#find the top start time for each city in the merged dataframe


top_start_times <- start_hr_merge %>%
  group_by(City, start.hour) %>%
  count() %>%
  na.omit() %>%
  top_n(1, wt = n) %>%
  arrange(City, desc(n))

# Find the most common start hour for each city
most_common_start_hour <- top_start_times %>%
  group_by(City) %>%
  filter(n == max(n)) %>%
  distinct(City, .keep_all = TRUE)

most_common_hour
# Out:
#   City start.hour n
# 1 chi  17         1039
# 2 nyc  17         5503
# 3 wash  8         9805

# %%
#referenced: https://r-graph-gallery.com/line-plot.html
# Plot the top start times for each city on a single bar plot
ggplot(top_start_times, aes(x = start.hour, y = n, color = City, group = City)) +
  geom_line() +
  geom_point() +
  geom_text(data = most_common_start_hour, aes(label = start.hour),
            vjust = -0.5, color = "black", size = 3) + 
  labs(title = "Top Start Times for Each City",
       x = "Start Hour",
       y = "Count",
       color = "City") +
  theme_minimal()
# Out:
# plot without title

# %%
#create new column called end.hour

create_end_hour_column <- function(data) {
  data %>%
    mutate(End.Time = ymd_hms(End.Time),  
           stop.hour = hour(End.Time))     
}

wash <- create_end_hour_column(wash)
ny <- create_end_hour_column(ny)
chi <- create_end_hour_column(chi)

wash
# Out:
#       X       Start.Time          End.Time            Trip.Duration
# 1     1621326 2017-06-21 08:36:34 2017-06-21 08:44:43  489.066
# 2      482740 2017-03-11 10:40:00 2017-03-11 10:46:00  402.549
# 3     1330037 2017-05-30 01:02:59 2017-05-30 01:13:37  637.251
# 4      665458 2017-04-02 07:48:35 2017-04-02 08:19:03 1827.341
# 5     1481135 2017-06-10 08:36:28 2017-06-10 09:02:17 1549.427
# 6     1148202 2017-05-14 07:18:18 2017-05-14 07:24:56  398.000
# 7     1594275 2017-06-19 08:41:43 2017-06-19 09:00:08 1105.429
# 8     1601832 2017-06-20 05:54:42 2017-06-20 06:05:18  636.218
# 9      574182 2017-03-24 20:37:00 2017-03-24 20:42:00  328.530
# 10     327058 2017-02-20 21:12:00 2017-02-20 21:31:00 1188.090
# 11     854729 2017-04-17 02:50:51 2017-04-17 03:05:17  866.689
# 12     721887 2017-04-08 01:12:48 2017-04-08 01:52:33 2385.411
# 13     143181 2017-01-26 20:01:00 2017-01-26 20:17:00  951.457
# 14      26953 2017-01-06 17:36:00 2017-01-06 17:43:00  448.628
# ...

# %%
#creating a new merged dataframe to work with
stop_hr_merge <- rbind(chi, ny)
stop_hr_merge


#need to drop the gender and birth year columns to merge with wash
stop_hr_merge <- stop_hr_merge %>%
  select(-c("Gender", "Birth.Year"))


#complete the merge
stop_hr_merge <- rbind(stop_hr_merge, wash)

stop_hr_merge
# Out:
#       X       Start.Time          End.Time            Trip.Duration
# 1     1423854 2017-06-23 15:09:32 2017-06-23 15:14:53  321
# 2      955915 2017-05-25 18:19:03 2017-05-25 18:45:53 1610
# 3        9031 2017-01-04 08:27:49 2017-01-04 08:34:45  416
# 4      304487 2017-03-06 13:49:38 2017-03-06 13:55:28  350
# 5       45207 2017-01-17 14:53:07 2017-01-17 15:02:01  534
# 6     1473887 2017-06-26 09:01:20 2017-06-26 09:11:06  586
# 7      961916 2017-05-26 09:41:44 2017-05-26 09:46:25  281
# 8       65924 2017-01-21 14:28:38 2017-01-21 14:40:41  723
# 9      606841 2017-04-20 16:08:51 2017-04-20 16:20:20  689
# 10     135470 2017-02-06 18:00:47 2017-02-06 18:09:00  493
# 11     175805 2017-02-15 07:09:55 2017-02-15 07:14:56  301
# 12      71678 2017-01-22 15:15:45 2017-01-22 15:31:02  917
# 13      19061 2017-01-08 16:03:00 2017-01-08 16:07:37  277
# 14    1023296 2017-05-30 15:46:18 2017-05-30 15:52:12  354
# 15     611000 2017-04-20 19:26:33 2017-04-20 19:35:08  515
# ...

# %%
#find the top start time for each city in the merged dataframe

top_stop_times <- stop_hr_merge %>%
  group_by(City, stop.hour) %>%
  count() %>%
  na.omit() %>%
  top_n(1, wt = n) %>%
  arrange(City, desc(n))

# Find the most common start hour for each city
most_common_stop_hour <- top_stop_times %>%
  group_by(City) %>%
  filter(n == max(n)) %>%
  distinct(City, .keep_all = TRUE)

most_common_stop_hour
# Out:
#   City stop.hour n
# 1 chi  17        1075
# 2 nyc  18        5544
# 3 wash  8        9948

# %%
# Plot the top start times for each city on a single bar plot
ggplot(top_stop_times, aes(x = stop.hour, y = n, color = City, group = City)) +
  geom_line() +
  geom_point() +
  geom_text(data = most_common_stop_hour, aes(label = stop.hour),
            vjust = -0.5, color = "black", size = 3) + 
  labs(title = "Top Stop Times for Each City",
       x = "Stop Hour",
       y = "Count",
       color = "City") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# ### Question 3
#
# #### What hour of the day are the most popular to start and stop rides?
#
# ###### Washington
#
# > In Washington, the popular starting and stopping hour are both 8am, which indicates the rides may be very short.
#
# ###### New York
#
# > In New York, the popular starting hour is 8am, but the ending hour is 6pm.
#
# ###### Chicago
#
# > In Chicago, the popular starting and stopping hour are both 5pm, which could also indicate the rides may be short.

# %% [markdown]
# ## Finishing Up
#
# > Congratulations!  You have reached the end of the Explore Bikeshare Data Project. You should be very proud of all you have accomplished!
#
# > **Tip**: Once you are satisfied with your work here, check over your report to make sure that it is satisfies all the areas of the [rubric](https://review.udacity.com/#!/rubrics/2508/view).
#
#
# ## Directions to Submit
#
# > Before you submit your project, you need to create a .html or .pdf version of this notebook in the workspace here. To do that, run the code cell below. If it worked correctly, you should get a return code of 0, and you should see the generated .html file in the workspace directory (click on the orange Jupyter icon in the upper left).
#
# > Alternatively, you can download this report as .html via the **File** > **Download as** submenu, and then manually upload it into the workspace directory by clicking on the orange Jupyter icon in the upper left, then using the Upload button.
#
# > Once you've done this, you can submit your project by clicking on the "Submit Project" button in the lower right here. This will create and submit a zip file with this .ipynb doc and the .html or .pdf version you created. Congratulations!

# %%
system('python -m nbconvert Explore_bikeshare_data.ipynb')
